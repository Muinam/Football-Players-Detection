# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6QxwIV5bvunrvdrkjNY4")
project = rf.workspace("inam-e2x8m").project("football-players-detection-3zvbc-swvjg")
version = project.version(3)
dataset = version.download("yolov8")

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load a pre-trained model (e.g., Nano version)
model = YOLO("yolov8n.pt")

# Train on your dataset
model.train(data=f"{dataset.location}/data.yaml", epochs=, imgsz=640)

# %%
model.predict(source=f"{dataset.location}/valid/images", save=True)

# %%
from IPython.display import Image, display
# Replace "path/to/your/output_image.jpg" with the actual path to an image file saved in the output directory (runs/detect/predict/)
display(Image(filename='/content/runs/detect/train2/2e57b9_1_7_png.rf.5bd7a7cb63b9e1e680d0c771173d9704.jpg'))

# %%
model.predict(source='/content/Cristiano Ronaldo - Juventus vs Real Madrid - bicycle kick goal.mp4', save=True)

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/runs/detect/predict/Cristiano Ronaldo - Juventus vs Real Madrid - bicycle kick goal.avi','rb').read()
data_url = "data:/content/runs/detect/predict2/abc.avi;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
